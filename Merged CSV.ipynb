# %%
import pandas as pd

# %%
cars_df = pd.read_csv('CSV_Files/cars.csv')

# %%
final_cars_df = cars_df[cars_df['Identification.Make'].isna() == False]
final_cars_df
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 4                 All-wheel drive
# ...                           ...
# 5071            Front-wheel drive
# 5072              All-wheel drive
# 5073              All-wheel drive
# 5074             Rear-wheel drive
# 5075             Rear-wheel drive
#
#                       Engine Information.Engine Type  \
# 0               Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# ...                                              ...
# 5071         Honda 3.5L 6 Cylinder 250 hp 253 ft-lbs
# 5072  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5073  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5074      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
# 5075      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
#
#       Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                          True                                           6
# 1                          True                                           6
# 2                          True                                           6
# 3                          True                                           6
# 4                          True                                           6
# ...                         ...                                         ...
# 5071                       True                                           5
# 5072                       True                                           6
# 5073                       True                                           6
# 5074                       True                                           6
# 5075                       True                                           6
#
#      Engine Information.Transmission  Fuel Information.City mpg  \
# 0     6 Speed Automatic Select Shift                         18
# 1     6 Speed Automatic Select Shift                         22
# 2                     6 Speed Manual                         21
# 3     6 Speed Automatic Select Shift                         21
# 4     6 Speed Automatic Select Shift                         21
# ...                              ...                        ...
# 5071               5 Speed Automatic                         18
# 5072                  6 Speed Manual                         12
# 5073                  6 Speed Manual                         12
# 5074  6 Speed Automatic Select Shift                         17
# 5075  6 Speed Automatic Select Shift                         17
#
#      Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# 0                      Gasoline                            25
# 1                      Gasoline                            28
# 2                      Gasoline                            30
# 3                      Gasoline                            28
# 4                      Gasoline                            28
# ...                         ...                           ...
# 5071                   Gasoline                            25
# 5072                   Gasoline                            20
# 5073                   Gasoline                            20
# 5074                   Gasoline                            25
# 5075                   Gasoline                            25
#
#      Identification.Classification                          Identification.ID  \
# 0           Automatic transmission                           2009 Audi A3 3.2
# 1           Automatic transmission                      2009 Audi A3 2.0 T AT
# 2              Manual transmission                         2009 Audi A3 2.0 T
# 3           Automatic transmission                 2009 Audi A3 2.0 T Quattro
# 4           Automatic transmission                 2009 Audi A3 2.0 T Quattro
# ...                            ...                                        ...
# 5071        Automatic transmission                      2012 Honda Pilot EX-L
# 5072           Manual transmission   2012 Lamborghini Gallardo Coupe LP 560-4
# 5073           Manual transmission  2012 Lamborghini Gallardo LP 560-4 Spyder
# 5074        Automatic transmission                        2012 BMW 740i Sedan
# 5075        Automatic transmission                       2012 BMW 740Li Sedan
#
#      Identification.Make         Identification.Model Year  \
# 0                   Audi                      2009 Audi A3
# 1                   Audi                      2009 Audi A3
# 2                   Audi                      2009 Audi A3
# 3                   Audi                      2009 Audi A3
# 4                   Audi                      2009 Audi A3
# ...                  ...                               ...
# 5071               Honda                  2012 Honda Pilot
# 5072         Lamborghini    2012 Lamborghini Gallardo Coup
# 5073         Lamborghini  2012 Lamborghini Gallardo Spyder
# 5074                 BMW                 2012 BMW 7 Series
# 5075                 BMW                 2012 BMW 7 Series
#
#       Identification.Year  Engine Information.Engine Statistics.Horsepower  \
# 0                    2009                                              250
# 1                    2009                                              200
# 2                    2009                                              200
# 3                    2009                                              200
# 4                    2009                                              200
# ...                   ...                                              ...
# 5071                 2012                                              250
# 5072                 2012                                              552
# 5073                 2012                                              552
# 5074                 2012                                              315
# 5075                 2012                                              315
#
#       Engine Information.Engine Statistics.Torque
# 0                                             236
# 1                                             207
# 2                                             207
# 3                                             207
# 4                                             207
# ...                                           ...
# 5071                                          253
# 5072                                          398
# 5073                                          398
# 5074                                          330
# 5075                                          330
#
# [5076 rows x 18 columns]

# %%
final_cars_df.astype({'Length': 'float64', 'Width': 'float64', 'Height': 'float64'}).dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-cf06115b1209> in <module>
# ----> 1 final_cars_df.astype({'Length': 'float64', 'Width': 'float64', 'Height': 'float64'}).dtypes
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5852             for col_name in dtype.keys():
#    5853                 if col_name not in self:
# -> 5854                     raise KeyError(
#    5855                         "Only a column name can be used for the "
#    5856                         "key in a dtype mappings argument."
#
# KeyError: 'Only a column name can be used for the key in a dtype mappings argument.'

# %%
#final_cars_df.count()

final_cars_df.rename(columns={'Dimensions.Height': 'Height',
                   'Dimensions.Length': 'Length',
                   'Dimensions.Width':'Width',
                   'Engine Information.Driveline': 'Drivetrain',
                   'Engine Information.Engine Type':'Engine_Type',
                   'Engine Information.Hybrid' : 'Hybrid',
                   'Engine Information.Number of Forward Gears': 'Gears',
                   'Engine Information.Transmission': 'Transmission',
                   'Fuel Information.City mpg' : 'City_MPG',
                   'Fuel Information.Highway mpg' : 'Highway_MPG',
                   'Fuel Information.Fuel Type': 'Fuel_Type',
                   'Identification.Classification': 'Cassification', 
                   'Identification.ID': 'Car Name',
                   'Identification.Make': 'Make',
                   'Identification.Model Year' : 'Model',
                   'Identification.Year' : 'Year',
                   'Engine Information.Engine Statistics.Horsepower': 'Horsepower',
                   'Engine Information.Engine Statistics.Torque': 'Torque'},  inplace=True)
final_cars_df.columns
# Out:
# Index(['Height', 'Length', 'Width', 'Drivetrain', 'Engine_Type', 'Hybrid',
#        'Gears', 'Transmission', 'City_MPG', 'Fuel_Type', 'Highway_MPG',
#        'Cassification', 'Car Name', 'Make', 'Model', 'Year', 'Horsepower',
#        'Torque'],
#       dtype='object')

# %%
cars = pd.DataFrame(final_cars_df)
cars.head()
# Out:
#    Height  Length  Width         Drivetrain  \
# 0     140     143    202    All-wheel drive
# 1     140     143    202  Front-wheel drive
# 2     140     143    202  Front-wheel drive
# 3     140     143    202    All-wheel drive
# 4     140     143    202    All-wheel drive
#
#                                     Engine_Type  Hybrid  Gears  \
# 0          Audi 3.2L 6 cylinder 250hp 236ft-lbs    True      6
# 1  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo    True      6
# 2  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo    True      6
# 3  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo    True      6
# 4  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo    True      6
#
#                      Transmission  City_MPG Fuel_Type  Highway_MPG  \
# 0  6 Speed Automatic Select Shift        18  Gasoline           25
# 1  6 Speed Automatic Select Shift        22  Gasoline           28
# 2                  6 Speed Manual        21  Gasoline           30
# 3  6 Speed Automatic Select Shift        21  Gasoline           28
# 4  6 Speed Automatic Select Shift        21  Gasoline           28
#
#             Cassification                    Car Name  Make         Model  \
# 0  Automatic transmission            2009 Audi A3 3.2  Audi  2009 Audi A3
# 1  Automatic transmission       2009 Audi A3 2.0 T AT  Audi  2009 Audi A3
# 2     Manual transmission          2009 Audi A3 2.0 T  Audi  2009 Audi A3
# 3  Automatic transmission  2009 Audi A3 2.0 T Quattro  Audi  2009 Audi A3
# 4  Automatic transmission  2009 Audi A3 2.0 T Quattro  Audi  2009 Audi A3
#
#    Year  Horsepower  Torque
# 0  2009         250     236
# 1  2009         200     207
# 2  2009         200     207
# 3  2009         200     207
# 4  2009         200     207

# %%
car_data_df = pd.read_csv('CSV_Files/car_data.csv')
car_data_df.head()
# Out:
#    Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0           1  alfa-romero       gas        std          two  convertible
# 1           2  alfa-romero       gas        std          two  convertible
# 2           3  alfa-romero       gas        std          two    hatchback
# 3           4         audi       gas        std         four        sedan
# 4           5         audi       gas        std         four        sedan
#
#   drive_wheels engine_location  wheel_base  length  ...  engine_type  \
# 0          rwd           front        88.6   168.8  ...         dohc
# 1          rwd           front        88.6   168.8  ...         dohc
# 2          rwd           front        94.5   171.2  ...         ohcv
# 3          fwd           front        99.8   176.6  ...          ohc
# 4          4wd           front        99.4   176.6  ...          ohc
#
#    num_of_cylinders  engine_size fuel_system compression_ratio  horsepower  \
# 0              four          130        mpfi               9.0         111
# 1              four          130        mpfi               9.0         111
# 2               six          152        mpfi               9.0         154
# 3              four          109        mpfi              10.0         102
# 4              five          136        mpfi               8.0         115
#
#   peak_rpm  city_mpg highway_mpg  price
# 0     5000        21          27  13495
# 1     5000        21          27  16500
# 2     5000        19          26  16500
# 3     5500        24          30  13950
# 4     5500        18          22  17450
#
# [5 rows x 23 columns]

# %%
final_car_data_df = car_data_df[car_data_df['make'].isna() == False]
#final_car_data_df.columns

# %%
final_car_data_df.dtypes
# Out:
# Unnamed: 0             int64
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors          object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders      object
# engine_size            int64
# fuel_system           object
# compression_ratio    float64
# horsepower            object
# peak_rpm              object
# city_mpg               int64
# highway_mpg            int64
# price                 object
# dtype: object

# %%
#final_cars_df.count()

final_car_data_df.rename(columns={'make':'Make', 
                              'fuel_type' :'Engine_Type', 
                              'aspiration' : 'Aspiration', 
                              'num_of_doors' : 'Number of Doors', 
                              'body_style' : "Body Style",
                              'drive_wheels': 'Drivetrain',
                              'engine_location' : 'Engine_Location',
                              'wheel_base' : 'Wheel Base', 
                              'length': 'Length', 
                              'width':'Width',
                              'height' : 'Height', 
                              'curb_weight' : 'Weight', 
                              'engine_type' : 'Engine Type', 
                              'num_of_cylinders' : 'Numner_Cylinders',
                              'engine_size': 'Engine Size', 
                              'fuel_system' : 'Fuel System', 
                              'compression_ratio' : 'Compression Ratio', 
                              'horsepower' : 'Horsepower',
                              'peak_rpm' : 'Peak_RPM', 
                              'city_mpg' : 'City_MPG', 
                              'highway_mpg' : 'Highway_MPG', 
                              'price' : 'Price'},  inplace=True)
final_car_data_df.dtypes
# Out:
# Unnamed: 0             int64
# Make                  object
# Engine_Type           object
# Aspiration            object
# Number of Doors       object
# Body Style            object
# Drivetrain            object
# Engine_Location       object
# Wheel Base           float64
# Length               float64
# Width                float64
# Height               float64
# Weight                 int64
# Engine Type           object
# Numner_Cylinders      object
# Engine Size            int64
# Fuel System           object
# Compression Ratio    float64
# Horsepower            object
# Peak_RPM              object
# City_MPG               int64
# Highway_MPG            int64
# Price                 object
# dtype: object

# %%
car = pd.DataFrame(final_car_data_df)
car
# Out:
#      Unnamed: 0         Make Engine_Type Aspiration Number of Doors  \
# 0             1  alfa-romero         gas        std             two
# 1             2  alfa-romero         gas        std             two
# 2             3  alfa-romero         gas        std             two
# 3             4         audi         gas        std            four
# 4             5         audi         gas        std            four
# ..          ...          ...         ...        ...             ...
# 200         201        volvo         gas        std            four
# 201         202        volvo         gas      turbo            four
# 202         203        volvo         gas        std            four
# 203         204        volvo      diesel      turbo            four
# 204         205        volvo         gas      turbo            four
#
#       Body Style Drivetrain Engine_Location  Wheel Base  Length  ...  \
# 0    convertible        rwd           front        88.6   168.8  ...
# 1    convertible        rwd           front        88.6   168.8  ...
# 2      hatchback        rwd           front        94.5   171.2  ...
# 3          sedan        fwd           front        99.8   176.6  ...
# 4          sedan        4wd           front        99.4   176.6  ...
# ..           ...        ...             ...         ...     ...  ...
# 200        sedan        rwd           front       109.1   188.8  ...
# 201        sedan        rwd           front       109.1   188.8  ...
# 202        sedan        rwd           front       109.1   188.8  ...
# 203        sedan        rwd           front       109.1   188.8  ...
# 204        sedan        rwd           front       109.1   188.8  ...
#
#      Engine Type  Numner_Cylinders  Engine Size Fuel System Compression Ratio  \
# 0           dohc              four          130        mpfi               9.0
# 1           dohc              four          130        mpfi               9.0
# 2           ohcv               six          152        mpfi               9.0
# 3            ohc              four          109        mpfi              10.0
# 4            ohc              five          136        mpfi               8.0
# ..           ...               ...          ...         ...               ...
# 200          ohc              four          141        mpfi               9.5
# 201          ohc              four          141        mpfi               8.7
# 202         ohcv               six          173        mpfi               8.8
# 203          ohc               six          145         idi              23.0
# 204          ohc              four          141        mpfi               9.5
#
#      Horsepower Peak_RPM  City_MPG Highway_MPG  Price
# 0           111     5000        21          27  13495
# 1           111     5000        21          27  16500
# 2           154     5000        19          26  16500
# 3           102     5500        24          30  13950
# 4           115     5500        18          22  17450
# ..          ...      ...       ...         ...    ...
# 200         114     5400        23          28  16845
# 201         160     5300        19          25  19045
# 202         134     5500        18          23  21485
# 203         106     4800        26          27  22470
# 204         114     5400        19          25  22625
#
# [205 rows x 23 columns]

# %%
final_df = pd.merge(cars, car, on=['Make', 
                                   'Engine_Type', 
                                   'Drivetrain', 
                                   'Length', 
                                   'Width', 
                                   'Height', 
                                   'City_MPG', 
                                   'Highway_MPG' ], how='outer')
final_df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1151: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
#       Height  Length  Width         Drivetrain  \
# 0      140.0   143.0  202.0    All-wheel drive
# 1      140.0   143.0  202.0  Front-wheel drive
# 2      140.0   143.0  202.0  Front-wheel drive
# 3      140.0   143.0  202.0    All-wheel drive
# 4      140.0   143.0  202.0    All-wheel drive
# ...      ...     ...    ...                ...
# 5276    55.5   188.8   68.9                rwd
# 5277    55.5   188.8   68.8                rwd
# 5278    55.5   188.8   68.9                rwd
# 5279    55.5   188.8   68.9                rwd
# 5280    55.5   188.8   68.9                rwd
#
#                                        Engine_Type Hybrid  Gears  \
# 0             Audi 3.2L 6 cylinder 250hp 236ft-lbs   True    6.0
# 1     Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True    6.0
# 2     Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True    6.0
# 3     Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True    6.0
# 4     Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True    6.0
# ...                                            ...    ...    ...
# 5276                                           gas    NaN    NaN
# 5277                                           gas    NaN    NaN
# 5278                                           gas    NaN    NaN
# 5279                                        diesel    NaN    NaN
# 5280                                           gas    NaN    NaN
#
#                         Transmission  City_MPG Fuel_Type  ...  Wheel Base  \
# 0     6 Speed Automatic Select Shift        18  Gasoline  ...         NaN
# 1     6 Speed Automatic Select Shift        22  Gasoline  ...         NaN
# 2                     6 Speed Manual        21  Gasoline  ...         NaN
# 3     6 Speed Automatic Select Shift        21  Gasoline  ...         NaN
# 4     6 Speed Automatic Select Shift        21  Gasoline  ...         NaN
# ...                              ...       ...       ...  ...         ...
# 5276                             NaN        23       NaN  ...       109.1
# 5277                             NaN        19       NaN  ...       109.1
# 5278                             NaN        18       NaN  ...       109.1
# 5279                             NaN        26       NaN  ...       109.1
# 5280                             NaN        19       NaN  ...       109.1
#
#       Weight Engine Type Numner_Cylinders Engine Size  Fuel System  \
# 0        NaN         NaN              NaN         NaN          NaN
# 1        NaN         NaN              NaN         NaN          NaN
# 2        NaN         NaN              NaN         NaN          NaN
# 3        NaN         NaN              NaN         NaN          NaN
# 4        NaN         NaN              NaN         NaN          NaN
# ...      ...         ...              ...         ...          ...
# 5276  2952.0         ohc             four       141.0         mpfi
# 5277  3049.0         ohc             four       141.0         mpfi
# 5278  3012.0        ohcv              six       173.0         mpfi
# 5279  3217.0         ohc              six       145.0          idi
# 5280  3062.0         ohc             four       141.0         mpfi
#
#       Compression Ratio  Horsepower_y  Peak_RPM  Price
# 0                   NaN           NaN       NaN    NaN
# 1                   NaN           NaN       NaN    NaN
# 2                   NaN           NaN       NaN    NaN
# 3                   NaN           NaN       NaN    NaN
# 4                   NaN           NaN       NaN    NaN
# ...                 ...           ...       ...    ...
# 5276                9.5           114      5400  16845
# 5277                8.7           160      5300  19045
# 5278                8.8           134      5500  21485
# 5279               23.0           106      4800  22470
# 5280                9.5           114      5400  22625
#
# [5281 rows x 33 columns]

# %%
#Googled to https://bit.ly/3yuOykQ
final_df['Size'] = final_df.Height * final_df.Length * final_df.Width
final_df['Average_MPG']=final_df.City_MPG+final_df.Highway_MPG/2
final_df = final_df.set_index("Size")
final_df.head()
# Out:
#            Height  Length  Width         Drivetrain  \
# Size
# 4044040.0   140.0   143.0  202.0    All-wheel drive
# 4044040.0   140.0   143.0  202.0  Front-wheel drive
# 4044040.0   140.0   143.0  202.0  Front-wheel drive
# 4044040.0   140.0   143.0  202.0    All-wheel drive
# 4044040.0   140.0   143.0  202.0    All-wheel drive
#
#                                             Engine_Type Hybrid  Gears  \
# Size
# 4044040.0          Audi 3.2L 6 cylinder 250hp 236ft-lbs   True    6.0
# 4044040.0  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True    6.0
# 4044040.0  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True    6.0
# 4044040.0  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True    6.0
# 4044040.0  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True    6.0
#
#                              Transmission  City_MPG Fuel_Type  ...  Weight  \
# Size                                                           ...
# 4044040.0  6 Speed Automatic Select Shift        18  Gasoline  ...     NaN
# 4044040.0  6 Speed Automatic Select Shift        22  Gasoline  ...     NaN
# 4044040.0                  6 Speed Manual        21  Gasoline  ...     NaN
# 4044040.0  6 Speed Automatic Select Shift        21  Gasoline  ...     NaN
# 4044040.0  6 Speed Automatic Select Shift        21  Gasoline  ...     NaN
#
#           Engine Type Numner_Cylinders Engine Size Fuel System  \
# Size
# 4044040.0         NaN              NaN         NaN         NaN
# 4044040.0         NaN              NaN         NaN         NaN
# 4044040.0         NaN              NaN         NaN         NaN
# 4044040.0         NaN              NaN         NaN         NaN
# 4044040.0         NaN              NaN         NaN         NaN
#
#            Compression Ratio  Horsepower_y  Peak_RPM  Price Average_MPG
# Size
# 4044040.0                NaN           NaN       NaN    NaN        30.5
# 4044040.0                NaN           NaN       NaN    NaN        36.0
# 4044040.0                NaN           NaN       NaN    NaN        36.0
# 4044040.0                NaN           NaN       NaN    NaN        35.0
# 4044040.0                NaN           NaN       NaN    NaN        35.0
#
# [5 rows x 34 columns]

# %%
final_df[['City_MPG', 'Highway_MPG','Average_MPG']]

size = final_df.groupby(['Size'])
size.count().head(10)

city_mpg = size["City_MPG"].mean()
#city_mpg

highway_mpg = size["Highway_MPG"].mean()
#highway_mpg

overall_mpg=size["Average_MPG"].mean()

size_mpg = pd.DataFrame({"Average City MPG": city_mpg, 
                         "Average Highway MPG": highway_mpg,
                        "Average_MPG":overall_mpg})
size_mpg

size_mpg.index.name = 'Size Inch^3'
size_mpg
# Out:
#              Average City MPG  Average Highway MPG  Average_MPG
# Size Inch^3
# 1476.0              14.000000            22.000000    25.000000
# 1824.0              19.000000            26.500000    32.250000
# 4416.0              19.000000            27.000000    32.500000
# 4800.0              19.000000            26.000000    32.000000
# 8547.0              13.250000            20.000000    23.250000
# ...                       ...                  ...          ...
# 11038518.0          12.000000            17.000000    20.500000
# 11100048.0          24.818182            33.545455    41.590909
# 12267280.0          22.000000            30.000000    37.000000
# 12461748.0          21.000000            28.000000    35.000000
# 12556236.0          24.000000            31.000000    39.500000
#
# [891 rows x 3 columns]

# %%
final_df['Average_MPG']=final_df.City_MPG+final_df.Highway_MPG/2
final_df[['City_MPG', 'Highway_MPG','Average_MPG','Price']]
price = final_df.groupby(['Price'])
price.count().head(10)

city_mpg = price["City_MPG"].mean()
#city_mpg

highway_mpg = price["Highway_MPG"].mean()
#highway_mpg

overall_mpg=price["Average_MPG"].mean()

price_mpg = pd.DataFrame({"Average City MPG": city_mpg, 
                         "Average Highway MPG": highway_mpg,
                        "Average_MPG":overall_mpg})
price_mpg

price_mpg.index.name = 'Price'
price_mpg
# Out:
#        Average City MPG  Average Highway MPG  Average_MPG
# Price
# 10198             25.00                 31.0        40.50
# 10245             26.00                 32.0        42.00
# 10295             27.00                 33.0        43.50
# 10345             25.00                 31.0        40.50
# 10595             26.00                 32.0        42.00
# ...                 ...                  ...          ...
# 9980              24.00                 29.0        38.50
# 9988              27.00                 32.0        43.00
# 9989              24.00                 30.0        39.00
# 9995              26.00                 32.0        42.00
# ?                 27.25                 34.0        44.25
#
# [187 rows x 3 columns]
