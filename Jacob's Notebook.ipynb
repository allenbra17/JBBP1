# %%
import pandas as pd
file = "CSV_Files/City_City_Zhvi_AllHomes.csv"

# %%
original_df = pd.read_csv(file)
original_df.head()
# Out:
#    RegionID    RegionName State                           Metro    CountyName  \
# 0      6181      New York    NY                        New York        Queens
# 1     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim   Los Angeles
# 2     17426       Chicago    IL                         Chicago          Cook
# 3     13271  Philadelphia    PA                    Philadelphia  Philadelphia
# 4     40326       Phoenix    AZ                         Phoenix      Maricopa
#
#    SizeRank   1996-04   1996-05   1996-06   1996-07  ...   2016-12  2017-01  \
# 0         1       NaN       NaN       NaN       NaN  ...  622800.0   626500
# 1         2  155000.0  154600.0  154400.0  154200.0  ...  608100.0   611000
# 2         3  109700.0  109400.0  109300.0  109300.0  ...  213900.0   216800
# 3         4   50000.0   49900.0   49600.0   49400.0  ...  132700.0   133800
# 4         5   87200.0   87700.0   88200.0   88400.0  ...  204800.0   206300
#
# ...

# %%
# Out:
# {'error': 'Not Found',
#  'message': '',
#  'path': '/api/summarized/IN',
#  'status': 404,
#  'timestamp': '2021-07-27T02:03:27.616+00:00'}
