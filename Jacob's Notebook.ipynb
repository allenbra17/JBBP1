# %%
import pandas as pd
file = "CSV_Files/City_City_Zhvi_AllHomes.csv"
file2 = "CSV_Files/IMPD_UCR_Current_Year.csv"
file3 = "CSV_Files/Indianapolis_Police_Zones.csv"
file4 = "CSV_Files/IMPD_Use_Of_Force.csv"

# %%
original_df = pd.read_csv(file3, low_memory=False)
original_df.head(40)
# Out:
#     OBJECTID          JURISDCTN   DISTRICT POLICEZONE     SHAPEAREA  \
# 0          1           Speedway   Excluded   Excluded  1.316124e+08
# 1          2           Lawrence   Excluded   Excluded  5.651537e+08
# 2          3               IMPD      North       ND70  6.274618e+08
# 3          4               IMPD  Northwest       NW10  6.389598e+07
# 4          5               IMPD      North       ND15  1.287695e+07
# 5          6               IMPD      North       ND16  2.378816e+07
# 6          7               IMPD  Southwest       SW80  2.684166e+08
# 7          8               IMPD   Downtown       DT10  2.572015e+07
# 8          9               IMPD   Downtown       DT20  1.974401e+07
# 9         10               IMPD  Southeast       SE50  3.430618e+08
# 10        11         Cumberland   Excluded   Excluded  2.147285e+07
# 11        12               IMPD  Northeast       NE26  2.060128e+07
# 12        13               IMPD  Southwest       SW15  4.902955e+07
# ...

# %%
original_df = pd.read_csv(file2, low_memory=False)
original_df.head(40)
# Out:
#     OBJECTID    UCR                       CRIME                     DATE_  \
# 0       3001  233.0  LARCENY-OVER 200-FROM AUTO  2017-01-25T00:00:00.000Z
# 1       3002  233.0  LARCENY-OVER 200-FROM AUTO  2017-01-25T00:00:00.000Z
# 2       3003  233.0  LARCENY-OVER 200-FROM AUTO  2017-01-25T00:00:00.000Z
# 3       3004  233.0  LARCENY-OVER 200-FROM AUTO  2017-01-25T00:00:00.000Z
# 4       3005  233.0  LARCENY-OVER 200-FROM AUTO  2017-01-25T00:00:00.000Z
# 5       3006  233.0  LARCENY-OVER 200-FROM AUTO  2017-01-26T00:00:00.000Z
# 6       3007  233.0  LARCENY-OVER 200-FROM AUTO  2017-01-26T00:00:00.000Z
# 7       3008  233.0  LARCENY-OVER 200-FROM AUTO  2017-01-26T00:00:00.000Z
# 8       3009  233.0  LARCENY-OVER 200-FROM AUTO  2017-01-26T00:00:00.000Z
# 9       3010  233.0  LARCENY-OVER 200-FROM AUTO  2017-01-26T00:00:00.000Z
# 10      3011  233.0  LARCENY-OVER 200-FROM AUTO  2017-01-26T00:00:00.000Z
# 11      3012  233.0  LARCENY-OVER 200-FROM AUTO  2017-01-26T00:00:00.000Z
# ...
