# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.float_format = '{:,.2f}'.format

# %%
cars_df = pd.read_csv('CSV_Files/cars.csv')

# %%
final_cars_df = cars_df[cars_df['Identification.Make'].isna() == False]
final_cars_df
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 4                 All-wheel drive
# ...                           ...
# 5071            Front-wheel drive
# 5072              All-wheel drive
# 5073              All-wheel drive
# 5074             Rear-wheel drive
# 5075             Rear-wheel drive
#
#                       Engine Information.Engine Type  \
# 0               Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# ...                                              ...
# 5071         Honda 3.5L 6 Cylinder 250 hp 253 ft-lbs
# 5072  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5073  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5074      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
# 5075      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
#
#       Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                          True                                           6
# 1                          True                                           6
# 2                          True                                           6
# 3                          True                                           6
# 4                          True                                           6
# ...                         ...                                         ...
# 5071                       True                                           5
# 5072                       True                                           6
# 5073                       True                                           6
# 5074                       True                                           6
# 5075                       True                                           6
#
#      Engine Information.Transmission  Fuel Information.City mpg  \
# 0     6 Speed Automatic Select Shift                         18
# 1     6 Speed Automatic Select Shift                         22
# 2                     6 Speed Manual                         21
# 3     6 Speed Automatic Select Shift                         21
# 4     6 Speed Automatic Select Shift                         21
# ...                              ...                        ...
# 5071               5 Speed Automatic                         18
# 5072                  6 Speed Manual                         12
# 5073                  6 Speed Manual                         12
# 5074  6 Speed Automatic Select Shift                         17
# 5075  6 Speed Automatic Select Shift                         17
#
#      Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# 0                      Gasoline                            25
# 1                      Gasoline                            28
# 2                      Gasoline                            30
# 3                      Gasoline                            28
# 4                      Gasoline                            28
# ...                         ...                           ...
# 5071                   Gasoline                            25
# 5072                   Gasoline                            20
# 5073                   Gasoline                            20
# 5074                   Gasoline                            25
# 5075                   Gasoline                            25
#
#      Identification.Classification                          Identification.ID  \
# 0           Automatic transmission                           2009 Audi A3 3.2
# 1           Automatic transmission                      2009 Audi A3 2.0 T AT
# 2              Manual transmission                         2009 Audi A3 2.0 T
# 3           Automatic transmission                 2009 Audi A3 2.0 T Quattro
# 4           Automatic transmission                 2009 Audi A3 2.0 T Quattro
# ...                            ...                                        ...
# 5071        Automatic transmission                      2012 Honda Pilot EX-L
# 5072           Manual transmission   2012 Lamborghini Gallardo Coupe LP 560-4
# 5073           Manual transmission  2012 Lamborghini Gallardo LP 560-4 Spyder
# 5074        Automatic transmission                        2012 BMW 740i Sedan
# 5075        Automatic transmission                       2012 BMW 740Li Sedan
#
#      Identification.Make         Identification.Model Year  \
# 0                   Audi                      2009 Audi A3
# 1                   Audi                      2009 Audi A3
# 2                   Audi                      2009 Audi A3
# 3                   Audi                      2009 Audi A3
# 4                   Audi                      2009 Audi A3
# ...                  ...                               ...
# 5071               Honda                  2012 Honda Pilot
# 5072         Lamborghini    2012 Lamborghini Gallardo Coup
# 5073         Lamborghini  2012 Lamborghini Gallardo Spyder
# 5074                 BMW                 2012 BMW 7 Series
# 5075                 BMW                 2012 BMW 7 Series
#
#       Identification.Year  Engine Information.Engine Statistics.Horsepower  \
# 0                    2009                                              250
# 1                    2009                                              200
# 2                    2009                                              200
# 3                    2009                                              200
# 4                    2009                                              200
# ...                   ...                                              ...
# 5071                 2012                                              250
# 5072                 2012                                              552
# 5073                 2012                                              552
# 5074                 2012                                              315
# 5075                 2012                                              315
#
#       Engine Information.Engine Statistics.Torque
# 0                                             236
# 1                                             207
# 2                                             207
# 3                                             207
# 4                                             207
# ...                                           ...
# 5071                                          253
# 5072                                          398
# 5073                                          398
# 5074                                          330
# 5075                                          330
#
# [5076 rows x 18 columns]

# %%
#final_cars_df.count()

final_cars_df.rename(columns={'Dimensions.Height': 'Height',
                   'Dimensions.Length': 'Length',
                   'Dimensions.Width':'Width',
                   'Engine Information.Driveline': 'Drivetrain',
                   'Engine Information.Engine Type':'Engine_Type',
                   'Engine Information.Hybrid' : 'Hybrid',
                   'Engine Information.Number of Forward Gears': 'Gears',
                   'Engine Information.Transmission': 'Transmission',
                   'Fuel Information.City mpg' : 'City_MPG',
                   'Fuel Information.Highway mpg' : 'Highway_MPG',
                   'Fuel Information.Fuel Type': 'Fuel_Type',
                   'Identification.Classification': 'Cassification', 
                   'Identification.ID': 'Car Name',
                   'Identification.Make': 'Make',
                   'Identification.Model Year' : 'Model',
                   'Identification.Year' : 'Year',
                   'Engine Information.Engine Statistics.Horsepower': 'Horsepower',
                   'Engine Information.Engine Statistics.Torque': 'Torque'},  inplace=True)
final_cars_df.dtypes
# Out:
# Height            int64
# Length            int64
# Width             int64
# Drivetrain       object
# Engine_Type      object
# Hybrid             bool
# Gears             int64
# Transmission     object
# City_MPG          int64
# Fuel_Type        object
# Highway_MPG       int64
# Cassification    object
# Car Name         object
# Make             object
# Model            object
# Year              int64
# Horsepower        int64
# Torque            int64
# dtype: object

# %%
# final_cars_df['Horsepower'] = final_cars_df(['Width', 'Height', 'Length'].astype(float))
# final_cars_df['Horsepower'] = final_cars_df['Horsepower'].astype(int)

# %%
cars = pd.DataFrame(final_cars_df)
cars
# Out:
#       Height  Length  Width         Drivetrain  \
# 0        140     143    202    All-wheel drive
# 1        140     143    202  Front-wheel drive
# 2        140     143    202  Front-wheel drive
# 3        140     143    202    All-wheel drive
# 4        140     143    202    All-wheel drive
# ...      ...     ...    ...                ...
# 5071      13     253    201  Front-wheel drive
# 5072     141     249    108    All-wheel drive
# 5073     160     249    108    All-wheel drive
# 5074     200     210    110   Rear-wheel drive
# 5075     200      94    110   Rear-wheel drive
#
#                                          Engine_Type  Hybrid  Gears  \
# 0               Audi 3.2L 6 cylinder 250hp 236ft-lbs    True      6
# 1       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo    True      6
# 2       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo    True      6
# 3       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo    True      6
# 4       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo    True      6
# ...                                              ...     ...    ...
# 5071         Honda 3.5L 6 Cylinder 250 hp 253 ft-lbs    True      5
# 5072  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs    True      6
# 5073  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs    True      6
# 5074      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo    True      6
# 5075      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo    True      6
#
#                         Transmission  City_MPG Fuel_Type  Highway_MPG  \
# 0     6 Speed Automatic Select Shift        18  Gasoline           25
# 1     6 Speed Automatic Select Shift        22  Gasoline           28
# 2                     6 Speed Manual        21  Gasoline           30
# 3     6 Speed Automatic Select Shift        21  Gasoline           28
# 4     6 Speed Automatic Select Shift        21  Gasoline           28
# ...                              ...       ...       ...          ...
# 5071               5 Speed Automatic        18  Gasoline           25
# 5072                  6 Speed Manual        12  Gasoline           20
# 5073                  6 Speed Manual        12  Gasoline           20
# 5074  6 Speed Automatic Select Shift        17  Gasoline           25
# 5075  6 Speed Automatic Select Shift        17  Gasoline           25
#
#                Cassification                                   Car Name  \
# 0     Automatic transmission                           2009 Audi A3 3.2
# 1     Automatic transmission                      2009 Audi A3 2.0 T AT
# 2        Manual transmission                         2009 Audi A3 2.0 T
# 3     Automatic transmission                 2009 Audi A3 2.0 T Quattro
# 4     Automatic transmission                 2009 Audi A3 2.0 T Quattro
# ...                      ...                                        ...
# 5071  Automatic transmission                      2012 Honda Pilot EX-L
# 5072     Manual transmission   2012 Lamborghini Gallardo Coupe LP 560-4
# 5073     Manual transmission  2012 Lamborghini Gallardo LP 560-4 Spyder
# 5074  Automatic transmission                        2012 BMW 740i Sedan
# 5075  Automatic transmission                       2012 BMW 740Li Sedan
#
#              Make                             Model  Year  Horsepower  Torque
# 0            Audi                      2009 Audi A3  2009         250     236
# 1            Audi                      2009 Audi A3  2009         200     207
# 2            Audi                      2009 Audi A3  2009         200     207
# 3            Audi                      2009 Audi A3  2009         200     207
# 4            Audi                      2009 Audi A3  2009         200     207
# ...           ...                               ...   ...         ...     ...
# 5071        Honda                  2012 Honda Pilot  2012         250     253
# 5072  Lamborghini    2012 Lamborghini Gallardo Coup  2012         552     398
# 5073  Lamborghini  2012 Lamborghini Gallardo Spyder  2012         552     398
# 5074          BMW                 2012 BMW 7 Series  2012         315     330
# 5075          BMW                 2012 BMW 7 Series  2012         315     330
#
# [5076 rows x 18 columns]

# %%
car_data_df = pd.read_csv('CSV_Files/car_data.csv', na_values='?')
car_data_df.dtypes
# Out:
# Unnamed: 0             int64
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors          object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders      object
# engine_size            int64
# fuel_system           object
# compression_ratio    float64
# horsepower           float64
# peak_rpm             float64
# city_mpg               int64
# highway_mpg            int64
# price                float64
# dtype: object

# %%
car_data_df[car_data_df['make'].isna() == False]
# Out:
#      Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0             1  alfa-romero       gas        std          two  convertible
# 1             2  alfa-romero       gas        std          two  convertible
# 2             3  alfa-romero       gas        std          two    hatchback
# 3             4         audi       gas        std         four        sedan
# 4             5         audi       gas        std         four        sedan
# ..          ...          ...       ...        ...          ...          ...
# 200         201        volvo       gas        std         four        sedan
# 201         202        volvo       gas      turbo         four        sedan
# 202         203        volvo       gas        std         four        sedan
# 203         204        volvo    diesel      turbo         four        sedan
# 204         205        volvo       gas      turbo         four        sedan
#
#     drive_wheels engine_location  wheel_base  length  ...  engine_type  \
# 0            rwd           front       88.60  168.80  ...         dohc
# 1            rwd           front       88.60  168.80  ...         dohc
# 2            rwd           front       94.50  171.20  ...         ohcv
# 3            fwd           front       99.80  176.60  ...          ohc
# 4            4wd           front       99.40  176.60  ...          ohc
# ..           ...             ...         ...     ...  ...          ...
# 200          rwd           front      109.10  188.80  ...          ohc
# 201          rwd           front      109.10  188.80  ...          ohc
# 202          rwd           front      109.10  188.80  ...         ohcv
# 203          rwd           front      109.10  188.80  ...          ohc
# 204          rwd           front      109.10  188.80  ...          ohc
#
#      num_of_cylinders  engine_size fuel_system compression_ratio  horsepower  \
# 0                four          130        mpfi              9.00      111.00
# 1                four          130        mpfi              9.00      111.00
# 2                 six          152        mpfi              9.00      154.00
# 3                four          109        mpfi             10.00      102.00
# 4                five          136        mpfi              8.00      115.00
# ..                ...          ...         ...               ...         ...
# 200              four          141        mpfi              9.50      114.00
# 201              four          141        mpfi              8.70      160.00
# 202               six          173        mpfi              8.80      134.00
# 203               six          145         idi             23.00      106.00
# 204              four          141        mpfi              9.50      114.00
#
#     peak_rpm  city_mpg  highway_mpg     price
# 0   5,000.00        21           27 13,495.00
# 1   5,000.00        21           27 16,500.00
# 2   5,000.00        19           26 16,500.00
# 3   5,500.00        24           30 13,950.00
# 4   5,500.00        18           22 17,450.00
# ..       ...       ...          ...       ...
# 200 5,400.00        23           28 16,845.00
# 201 5,300.00        19           25 19,045.00
# 202 5,500.00        18           23 21,485.00
# 203 4,800.00        26           27 22,470.00
# 204 5,400.00        19           25 22,625.00
#
# [205 rows x 23 columns]

# %%
car_data_df.dtypes
# Out:
# Unnamed: 0             int64
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors          object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders      object
# engine_size            int64
# fuel_system           object
# compression_ratio    float64
# horsepower           float64
# peak_rpm             float64
# city_mpg               int64
# highway_mpg            int64
# price                float64
# dtype: object

# %%
car_data_df.rename(columns={'make':'Make', 
                              'fuel_type' :'Fuel_Type', 
                              'aspiration' : 'Aspiration', 
                              'num_of_doors' : 'Number of Doors', 
                              'body_style' : "Body Style",
                              'drive_wheels': 'Drivetrain',
                              'engine_location' : 'Engine_Location',
                              'wheel_base' : 'Wheel Base', 
                              'length': 'Length', 
                              'width':'Width',
                              'height' : 'Height', 
                              'curb_weight' : 'Weight', 
                              'engine_type' : 'EngineType', 
                              'num_of_cylinders' : 'Numner_Cylinders',
                              'engine_size': 'Engine_Size', 
                              'fuel_system' : 'Fuel_System', 
                              'compression_ratio' : 'Compression Ratio', 
                              'horsepower' : 'Horsepower',
                              'peak_rpm' : 'Peak_RPM', 
                              'city_mpg' : 'City_MPG', 
                              'highway_mpg' : 'Highway_MPG',
                                'price': 'Price'},  inplace=True) 
car_data_df.dtypes
# Out:
# Unnamed: 0             int64
# Make                  object
# Fuel_Type             object
# Aspiration            object
# Number of Doors       object
# Body Style            object
# Drivetrain            object
# Engine_Location       object
# Wheel Base           float64
# Length               float64
# Width                float64
# Height               float64
# Weight                 int64
# EngineType            object
# Numner_Cylinders      object
# Engine_Size            int64
# Fuel_System           object
# Compression Ratio    float64
# Horsepower           float64
# Peak_RPM             float64
# City_MPG               int64
# Highway_MPG            int64
# Price                float64
# dtype: object

# %%
#final_car_data_df = car_data_df[car_data_df['make'].isna() == False]
# final_car_data_df[final_car_data_df['horsepower'].isin(['?'])]
#car_data_df[car_data_df["Price"].str.contains("?")==False]
#car_data_df.drop(car_data_df[car_data_df.Horsepower.str.contains('?')])

# %%
#car_data_df['Horsepower'].to_numeric()
#new_df['Horsepower'] = new_df['Horsepower'].astype(int)
#car_data_df['Price'] = car_data_df['Price'].astype(int)
#car_data_df.dtypes

# %%
car = pd.DataFrame(car_data_df)
car
# Out:
#      Unnamed: 0         Make Fuel_Type Aspiration Number of Doors  \
# 0             1  alfa-romero       gas        std             two
# 1             2  alfa-romero       gas        std             two
# 2             3  alfa-romero       gas        std             two
# 3             4         audi       gas        std            four
# 4             5         audi       gas        std            four
# ..          ...          ...       ...        ...             ...
# 200         201        volvo       gas        std            four
# 201         202        volvo       gas      turbo            four
# 202         203        volvo       gas        std            four
# 203         204        volvo    diesel      turbo            four
# 204         205        volvo       gas      turbo            four
#
#       Body Style Drivetrain Engine_Location  Wheel Base  Length  ...  \
# 0    convertible        rwd           front       88.60  168.80  ...
# 1    convertible        rwd           front       88.60  168.80  ...
# 2      hatchback        rwd           front       94.50  171.20  ...
# 3          sedan        fwd           front       99.80  176.60  ...
# 4          sedan        4wd           front       99.40  176.60  ...
# ..           ...        ...             ...         ...     ...  ...
# 200        sedan        rwd           front      109.10  188.80  ...
# 201        sedan        rwd           front      109.10  188.80  ...
# 202        sedan        rwd           front      109.10  188.80  ...
# 203        sedan        rwd           front      109.10  188.80  ...
# 204        sedan        rwd           front      109.10  188.80  ...
#
#      EngineType  Numner_Cylinders  Engine_Size Fuel_System Compression Ratio  \
# 0          dohc              four          130        mpfi              9.00
# 1          dohc              four          130        mpfi              9.00
# 2          ohcv               six          152        mpfi              9.00
# 3           ohc              four          109        mpfi             10.00
# 4           ohc              five          136        mpfi              8.00
# ..          ...               ...          ...         ...               ...
# 200         ohc              four          141        mpfi              9.50
# 201         ohc              four          141        mpfi              8.70
# 202        ohcv               six          173        mpfi              8.80
# 203         ohc               six          145         idi             23.00
# 204         ohc              four          141        mpfi              9.50
#
#      Horsepower Peak_RPM  City_MPG  Highway_MPG     Price
# 0        111.00 5,000.00        21           27 13,495.00
# 1        111.00 5,000.00        21           27 16,500.00
# 2        154.00 5,000.00        19           26 16,500.00
# 3        102.00 5,500.00        24           30 13,950.00
# 4        115.00 5,500.00        18           22 17,450.00
# ..          ...      ...       ...          ...       ...
# 200      114.00 5,400.00        23           28 16,845.00
# 201      160.00 5,300.00        19           25 19,045.00
# 202      134.00 5,500.00        18           23 21,485.00
# 203      106.00 4,800.00        26           27 22,470.00
# 204      114.00 5,400.00        19           25 22,625.00
#
# [205 rows x 23 columns]

# %%
car['Make'] = car['Make'].str.upper()
cars['Make'] = cars['Make'].str.upper()
final_df = pd.merge(cars, car, on=['Make', 
                                   'Fuel_Type', 
                                   'Drivetrain', 
                                   'Length', 
                                   'Width', 
                                   'Height', 
                                   'City_MPG', 
                                   'Highway_MPG',
                                   'Horsepower' ], how='outer')
final_df
# Out:
# C:\Users\13174\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py:1151: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
#       Height  Length  Width         Drivetrain  \
# 0     140.00  143.00 202.00    All-wheel drive
# 1     140.00  143.00 202.00  Front-wheel drive
# 2     140.00  143.00 202.00  Front-wheel drive
# 3     140.00  143.00 202.00    All-wheel drive
# 4     140.00  143.00 202.00    All-wheel drive
# ...      ...     ...    ...                ...
# 5276   55.50  188.80  68.90                rwd
# 5277   55.50  188.80  68.80                rwd
# 5278   55.50  188.80  68.90                rwd
# 5279   55.50  188.80  68.90                rwd
# 5280   55.50  188.80  68.90                rwd
#
#                                        Engine_Type Hybrid  Gears  \
# 0             Audi 3.2L 6 cylinder 250hp 236ft-lbs   True   6.00
# 1     Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True   6.00
# 2     Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True   6.00
# 3     Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True   6.00
# 4     Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True   6.00
# ...                                            ...    ...    ...
# 5276                                           NaN    NaN    NaN
# 5277                                           NaN    NaN    NaN
# 5278                                           NaN    NaN    NaN
# 5279                                           NaN    NaN    NaN
# 5280                                           NaN    NaN    NaN
#
#                         Transmission  City_MPG Fuel_Type  ...  \
# 0     6 Speed Automatic Select Shift        18  Gasoline  ...
# 1     6 Speed Automatic Select Shift        22  Gasoline  ...
# 2                     6 Speed Manual        21  Gasoline  ...
# 3     6 Speed Automatic Select Shift        21  Gasoline  ...
# 4     6 Speed Automatic Select Shift        21  Gasoline  ...
# ...                              ...       ...       ...  ...
# 5276                             NaN        23       gas  ...
# 5277                             NaN        19       gas  ...
# 5278                             NaN        18       gas  ...
# 5279                             NaN        26    diesel  ...
# 5280                             NaN        19       gas  ...
#
#       Engine_Location Wheel Base   Weight EngineType Numner_Cylinders  \
# 0                 NaN        NaN      NaN        NaN              NaN
# 1                 NaN        NaN      NaN        NaN              NaN
# 2                 NaN        NaN      NaN        NaN              NaN
# 3                 NaN        NaN      NaN        NaN              NaN
# 4                 NaN        NaN      NaN        NaN              NaN
# ...               ...        ...      ...        ...              ...
# 5276            front     109.10 2,952.00        ohc             four
# 5277            front     109.10 3,049.00        ohc             four
# 5278            front     109.10 3,012.00       ohcv              six
# 5279            front     109.10 3,217.00        ohc              six
# 5280            front     109.10 3,062.00        ohc             four
#
#       Engine_Size  Fuel_System  Compression Ratio  Peak_RPM     Price
# 0             NaN          NaN                NaN       NaN       NaN
# 1             NaN          NaN                NaN       NaN       NaN
# 2             NaN          NaN                NaN       NaN       NaN
# 3             NaN          NaN                NaN       NaN       NaN
# 4             NaN          NaN                NaN       NaN       NaN
# ...           ...          ...                ...       ...       ...
# 5276       141.00         mpfi               9.50  5,400.00 16,845.00
# 5277       141.00         mpfi               8.70  5,300.00 19,045.00
# 5278       173.00         mpfi               8.80  5,500.00 21,485.00
# 5279       145.00          idi              23.00  4,800.00 22,470.00
# 5280       141.00         mpfi               9.50  5,400.00 22,625.00
#
# [5281 rows x 32 columns]

# %%
final_df.drop(['Unnamed: 0'], axis=1)
# Out:
#       Height  Length  Width         Drivetrain  \
# 0     140.00  143.00 202.00    All-wheel drive
# 1     140.00  143.00 202.00  Front-wheel drive
# 2     140.00  143.00 202.00  Front-wheel drive
# 3     140.00  143.00 202.00    All-wheel drive
# 4     140.00  143.00 202.00    All-wheel drive
# ...      ...     ...    ...                ...
# 5276   55.50  188.80  68.90                rwd
# 5277   55.50  188.80  68.80                rwd
# 5278   55.50  188.80  68.90                rwd
# 5279   55.50  188.80  68.90                rwd
# 5280   55.50  188.80  68.90                rwd
#
#                                        Engine_Type Hybrid  Gears  \
# 0             Audi 3.2L 6 cylinder 250hp 236ft-lbs   True   6.00
# 1     Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True   6.00
# 2     Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True   6.00
# 3     Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True   6.00
# 4     Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True   6.00
# ...                                            ...    ...    ...
# 5276                                           NaN    NaN    NaN
# 5277                                           NaN    NaN    NaN
# 5278                                           NaN    NaN    NaN
# 5279                                           NaN    NaN    NaN
# 5280                                           NaN    NaN    NaN
#
#                         Transmission  City_MPG Fuel_Type  ...  \
# 0     6 Speed Automatic Select Shift        18  Gasoline  ...
# 1     6 Speed Automatic Select Shift        22  Gasoline  ...
# 2                     6 Speed Manual        21  Gasoline  ...
# 3     6 Speed Automatic Select Shift        21  Gasoline  ...
# 4     6 Speed Automatic Select Shift        21  Gasoline  ...
# ...                              ...       ...       ...  ...
# 5276                             NaN        23       gas  ...
# 5277                             NaN        19       gas  ...
# 5278                             NaN        18       gas  ...
# 5279                             NaN        26    diesel  ...
# 5280                             NaN        19       gas  ...
#
#       Engine_Location Wheel Base   Weight EngineType Numner_Cylinders  \
# 0                 NaN        NaN      NaN        NaN              NaN
# 1                 NaN        NaN      NaN        NaN              NaN
# 2                 NaN        NaN      NaN        NaN              NaN
# 3                 NaN        NaN      NaN        NaN              NaN
# 4                 NaN        NaN      NaN        NaN              NaN
# ...               ...        ...      ...        ...              ...
# 5276            front     109.10 2,952.00        ohc             four
# 5277            front     109.10 3,049.00        ohc             four
# 5278            front     109.10 3,012.00       ohcv              six
# 5279            front     109.10 3,217.00        ohc              six
# 5280            front     109.10 3,062.00        ohc             four
#
#       Engine_Size  Fuel_System  Compression Ratio Peak_RPM     Price
# 0             NaN          NaN                NaN      NaN       NaN
# 1             NaN          NaN                NaN      NaN       NaN
# 2             NaN          NaN                NaN      NaN       NaN
# 3             NaN          NaN                NaN      NaN       NaN
# 4             NaN          NaN                NaN      NaN       NaN
# ...           ...          ...                ...      ...       ...
# 5276       141.00         mpfi               9.50 5,400.00 16,845.00
# 5277       141.00         mpfi               8.70 5,300.00 19,045.00
# 5278       173.00         mpfi               8.80 5,500.00 21,485.00
# 5279       145.00          idi              23.00 4,800.00 22,470.00
# 5280       141.00         mpfi               9.50 5,400.00 22,625.00
#
# [5281 rows x 31 columns]

# %%
final_df['Drivetrain'].replace({'4wd':'Four Wheel Drive', 
                              'Four-wheel drive' :'Four Wheel Drive', 
                              'All-wheel drive' : 'All Wheel Drive', 
                              'Front-wheel drive' : 'Front Wheel Drive', 
                              'fwd' : "Front Wheel Drive",
                              'Rear-wheel drive': 'Rear Wheel Drive',
                              'rwd' : 'Rear Wheel Drive'},  inplace=True)

# %%
final_df['Year'].astype('string')
# Out:
# 0       2009.0
# 1       2009.0
# 2       2009.0
# 3       2009.0
# 4       2009.0
#          ...
# 5276      <NA>
# 5277      <NA>
# 5278      <NA>
# 5279      <NA>
# 5280      <NA>
# Name: Year, Length: 5281, dtype: string

# %%
new_df = final_df.set_index("Make")
new_df
# Out:
#        Height  Length  Width         Drivetrain  \
# Make
# AUDI   140.00  143.00 202.00    All Wheel Drive
# AUDI   140.00  143.00 202.00  Front Wheel Drive
# AUDI   140.00  143.00 202.00  Front Wheel Drive
# AUDI   140.00  143.00 202.00    All Wheel Drive
# AUDI   140.00  143.00 202.00    All Wheel Drive
# ...       ...     ...    ...                ...
# VOLVO   55.50  188.80  68.90   Rear Wheel Drive
# VOLVO   55.50  188.80  68.80   Rear Wheel Drive
# VOLVO   55.50  188.80  68.90   Rear Wheel Drive
# VOLVO   55.50  188.80  68.90   Rear Wheel Drive
# VOLVO   55.50  188.80  68.90   Rear Wheel Drive
#
#                                         Engine_Type Hybrid  Gears  \
# Make
# AUDI           Audi 3.2L 6 cylinder 250hp 236ft-lbs   True   6.00
# AUDI   Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True   6.00
# AUDI   Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True   6.00
# AUDI   Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True   6.00
# AUDI   Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo   True   6.00
# ...                                             ...    ...    ...
# VOLVO                                           NaN    NaN    NaN
# VOLVO                                           NaN    NaN    NaN
# VOLVO                                           NaN    NaN    NaN
# VOLVO                                           NaN    NaN    NaN
# VOLVO                                           NaN    NaN    NaN
#
#                          Transmission  City_MPG Fuel_Type  ...  \
# Make                                                       ...
# AUDI   6 Speed Automatic Select Shift        18  Gasoline  ...
# AUDI   6 Speed Automatic Select Shift        22  Gasoline  ...
# AUDI                   6 Speed Manual        21  Gasoline  ...
# AUDI   6 Speed Automatic Select Shift        21  Gasoline  ...
# AUDI   6 Speed Automatic Select Shift        21  Gasoline  ...
# ...                               ...       ...       ...  ...
# VOLVO                             NaN        23       gas  ...
# VOLVO                             NaN        19       gas  ...
# VOLVO                             NaN        18       gas  ...
# VOLVO                             NaN        26    diesel  ...
# VOLVO                             NaN        19       gas  ...
#
#        Engine_Location Wheel Base   Weight EngineType  Numner_Cylinders  \
# Make
# AUDI               NaN        NaN      NaN        NaN               NaN
# AUDI               NaN        NaN      NaN        NaN               NaN
# AUDI               NaN        NaN      NaN        NaN               NaN
# AUDI               NaN        NaN      NaN        NaN               NaN
# AUDI               NaN        NaN      NaN        NaN               NaN
# ...                ...        ...      ...        ...               ...
# VOLVO            front     109.10 2,952.00        ohc              four
# VOLVO            front     109.10 3,049.00        ohc              four
# VOLVO            front     109.10 3,012.00       ohcv               six
# VOLVO            front     109.10 3,217.00        ohc               six
# VOLVO            front     109.10 3,062.00        ohc              four
#
#        Engine_Size  Fuel_System  Compression Ratio Peak_RPM     Price
# Make
# AUDI           NaN          NaN                NaN      NaN       NaN
# AUDI           NaN          NaN                NaN      NaN       NaN
# AUDI           NaN          NaN                NaN      NaN       NaN
# AUDI           NaN          NaN                NaN      NaN       NaN
# AUDI           NaN          NaN                NaN      NaN       NaN
# ...            ...          ...                ...      ...       ...
# VOLVO       141.00         mpfi               9.50 5,400.00 16,845.00
# VOLVO       141.00         mpfi               8.70 5,300.00 19,045.00
# VOLVO       173.00         mpfi               8.80 5,500.00 21,485.00
# VOLVO       145.00          idi              23.00 4,800.00 22,470.00
# VOLVO       141.00         mpfi               9.50 5,400.00 22,625.00
#
# [5281 rows x 31 columns]

# %%
new_df[['City_MPG', 'Highway_MPG']]
# Out:
#        City_MPG  Highway_MPG
# Make
# AUDI         18           25
# AUDI         22           28
# AUDI         21           30
# AUDI         21           28
# AUDI         21           28
# ...         ...          ...
# VOLVO        23           28
# VOLVO        19           25
# VOLVO        18           23
# VOLVO        26           27
# VOLVO        19           25
#
# [5281 rows x 2 columns]

# %%
# city_average = new_df['City_MPG'].mean()
# highway_average = new_df['Highway_MPG'].mean()
# city_average,highway_average

# %%
city_average = new_df['City_MPG'].dropna()
highway_average = new_df['Highway_MPG'].dropna()
city_average.mean(),highway_average.mean()
# Out:
# (17.584169664836207, 24.382692671842452)

# %%
mpgs = new_df.groupby('Make')
mpgs

avg_city = mpgs.mean()["City_MPG"]
#avg_city

avg_highway = mpgs.mean()["Highway_MPG"]
#avg_highway

total_avg = (avg_city + avg_highway) / 2

avg_mpg = pd.DataFrame({"Average City MPG": avg_city, 
                        "Average Highway MPG": avg_highway,
                       "Total Average MPG" : total_avg})
avg_mpg.index.name = 'Make'
new_avg = avg_mpg.dropna()
sorted_avg = new_avg.sort_values(by='Total Average MPG', ascending=False)
sorted_avg
# Out:
#                     Average City MPG  Average Highway MPG  Total Average MPG
# Make
# ISUZU                          31.00                36.00              33.50
# PLYMOUTH                       28.14                34.14              31.14
# MINI                           26.16                33.87              30.02
# KIA                            23.07                30.95              27.01
# RENAULT                        23.00                31.00              27.00
# HONDA                          22.53                30.72              26.62
# VOLKSWAGEN                     22.45                30.60              26.52
# SCION                          23.15                29.85              26.50
# HYUNDAI                        21.77                30.19              25.98
# MAZDA                          21.08                28.25              24.66
# PEUGOT                         22.45                26.64              24.55
# MITSUBISHI                     20.34                27.59              23.97
# SUBARU                         20.38                26.97              23.68
# ALFA-ROMERO                    20.33                26.67              23.50
# LOTUS                          20.00                26.36              23.18
# SAAB                           18.54                27.51              23.02
# SUZUKI                         19.24                25.92              22.58
# VOLVO                          18.66                25.73              22.19
# ACURA                          18.45                25.85              22.15
# BMW MOTORRAD                   17.60                26.59              22.09
# TOYOTA                         18.97                24.74              21.86
# LEXUS                          17.77                25.25              21.51
# CHRYSLER                       17.20                25.77              21.48
# BUICK                          17.21                25.73              21.47
# AUDI                           17.56                25.10              21.33
# MERCURY                        18.03                24.41              21.22
# INFINITI                       17.05                24.29              20.67
# PORSCHE                        16.96                24.18              20.57
# BMW                            16.74                24.38              20.56
# CHEVROLET                      16.46                24.06              20.26
# JEEP                           17.57                22.57              20.07
# CHRYSLER GROUP LLC             16.33                23.33              19.83
# MERCEDES                       16.25                23.16              19.70
# NISSAN                         16.27                21.99              19.13
# CADILLAC                       15.57                22.52              19.05
# MERCEDES-BENZ                  16.60                20.73              18.67
# JAGUAR                         15.28                21.94              18.61
# FORD                           15.65                21.54              18.60
# LINCOLN                        15.26                21.47              18.36
# DODGE                          15.04                21.16              18.10
# GRAND CHEROKEE                 14.23                20.08              17.16
# GMC                            14.36                19.83              17.10
# LAND ROVER                     13.34                19.54              16.44
# LAMBORGHINI                    12.00                20.00              16.00
# MASERATI                       12.17                19.42              15.79
# AMG                            12.40                18.90              15.65
# ASTON MARTIN                   12.33                18.44              15.38
# ROLLS-ROYCE                    11.40                18.40              14.90
# MERCEDES-AMG                   11.83                16.83              14.33
# MAYBACH                        10.00                16.00              13.00
# BENTLEY                         9.61                16.22              12.92
# FERRARI                         9.00                16.00              12.50

# %%
fig = plt.figure(figsize=(20,15))
plt.xticks(rotation=90)
plt.plot(sorted_avg)
# Out:
# [<matplotlib.lines.Line2D at 0x292a0ba83a0>,
#  <matplotlib.lines.Line2D at 0x292a0ba8490>,
#  <matplotlib.lines.Line2D at 0x292a0ba8100>]

# %%
horsepower_df = final_df.groupby(['Drivetrain'])
#horsepower_df.count().head(10)

horsepower = horsepower_df["Horsepower"].mean()
#horsepower

torque = horsepower_df["Torque"].mean()
#torque

hoursepower_torque = pd.DataFrame({"Average Horsepower": horsepower, 
                           "Average Torque": torque})

hoursepower_torque.index.name = 'Drivetrain'
new_horse = hoursepower_torque.dropna()
new_horse
# Out:
#                    Average Horsepower  Average Torque
# Drivetrain
# All Wheel Drive                285.66          277.84
# Four Wheel Drive               289.65          311.18
# Front Wheel Drive              184.53          186.24
# Rear Wheel Drive               314.74          327.52

# %%
plt.plot(new_horse)
# Out:
# [<matplotlib.lines.Line2D at 0x292a0c7a2b0>,
#  <matplotlib.lines.Line2D at 0x292a0c7a370>]

# %%
drivetrain_df = new_df.groupby(['Drivetrain'])
#drivetrain_df.count().head(10)

city_mpg = drivetrain_df["City_MPG"].mean()
city_mpg

highway_mpg = drivetrain_df["Highway_MPG"].mean()
#highway_mpg

drivetrain = pd.DataFrame({"Average City MPG": city_mpg, 
                           "Average Highway MPG": highway_mpg})
#avg_mpg

drivetrain.index.name = 'Drivetrain'
drivetrain
# Out:
#                    Average City MPG  Average Highway MPG
# Drivetrain
# All Wheel Drive               16.84                23.63
# Four Wheel Drive              14.37                19.38
# Front Wheel Drive             22.06                30.05
# Rear Wheel Drive              15.42                22.03

# %%
plt.plot(drivetrain)
# Out:
# [<matplotlib.lines.Line2D at 0x292a0cd9790>,
#  <matplotlib.lines.Line2D at 0x292a0cd9850>]

# %%
year = final_df.groupby(['Year'])
year.format='%Y'
#year.count().head(10)

city_mpg = year["City_MPG"].mean()
#city_mpg

highway_mpg = year["Highway_MPG"].mean()
#highway_mpg

year_mpg = pd.DataFrame({"Average City MPG": city_mpg, 
                         "Average Highway MPG": highway_mpg})


#year_mpg.index.astype('')

year_mpg.index.name = 'Year'
year_mpg
# Out:
#           Average City MPG  Average Highway MPG
# Year
# 2,009.00             17.86                24.31
# 2,010.00             17.01                23.61
# 2,011.00             16.89                23.60
# 2,012.00             18.28                25.74

# %%
plt.plot(year_mpg)
# Out:
# [<matplotlib.lines.Line2D at 0x292a0d295b0>,
#  <matplotlib.lines.Line2D at 0x292a0d295e0>]

# %%
car_data_df['Size'] = car_data_df.Height * car_data_df.Length * car_data_df.Width
#final_df

size = car_data_df.groupby(['Size'])

city_mpg = size["City_MPG"].mean()
#city_mpg

highway_mpg = size["Highway_MPG"].mean()
#highway_mpg

size_df = pd.DataFrame({"Average City MPG": city_mpg, 
                         "Average Highway MPG": highway_mpg})


#year_mpg.index.astype('')

size_df.index.name = 'Size'
size_df
# Out:
#             Average City MPG  Average Highway MPG
# Size
# 452,643.16             47.00                53.00
# 469,388.95             40.00                46.00
# 504,960.00             32.67                36.67
# 507,808.44             29.60                36.40
# 509,815.59             29.50                35.00
# ...                      ...                  ...
# 794,568.96             14.00                16.00
# 798,599.41             23.00                24.67
# 817,837.45             22.00                25.00
# 820,742.73             16.00                18.00
# 846,007.66             14.00                16.00
#
# [97 rows x 2 columns]

# %%
plt.plot(size_df)
# Out:
# [<matplotlib.lines.Line2D at 0x292a0d846d0>,
#  <matplotlib.lines.Line2D at 0x292a0d84700>]

# %%
car_data_df['Average_MPG'] = (car_data_df.Highway_MPG * car_data_df.Highway_MPG) / 2

price = car_data_df.groupby(['Price'])


city_mpg = price["City_MPG"].mean()
city_mpg

highway_mpg = price["Highway_MPG"].mean()
highway_mpg

price_mpg = pd.DataFrame({"Average City MPG": city_mpg, 
                          "Average Highway MPG": highway_mpg})
price_mpg

price_mpg.index.name = 'Price'
price_mpg
sorted_avg = price_mpg.sort_values(by='Price', ascending=False)
sorted_avg
# Out:
#            Average City MPG  Average Highway MPG
# Price
# 45,400.00             14.00                16.00
# 41,315.00             16.00                22.00
# 40,960.00             14.00                16.00
# 37,028.00             17.00                25.00
# 36,880.00             15.00                20.00
# ...                     ...                  ...
# 5,389.00              37.00                41.00
# 5,348.00              35.00                39.00
# 5,195.00              30.00                31.00
# 5,151.00              47.00                53.00
# 5,118.00              31.00                36.00
#
# [186 rows x 2 columns]

# %%
plt.plot(sorted_avg)
# Out:
# [<matplotlib.lines.Line2D at 0x292a0dfb250>,
#  <matplotlib.lines.Line2D at 0x292a0dfb280>]

# %%
final_df['Fuel_Type'].replace({'gas':'Gasoline', 
                              'diesel' :'Diesel',
                               'Diesel fuel': 'Diesel',
                              'Compressed natural gas': 'Natural Gas'},  inplace=True)
#final_df['Fuel_Type']

fuel_df = final_df.groupby(['Fuel_Type'])
#horsepower_df.count().head(10)

city_mpg = fuel_df["City_MPG"].mean()
#city_mpg

highway_mpg = fuel_df["Highway_MPG"].mean()
#highway_mpg

fuel_mpg = pd.DataFrame({"Average City MPG": city_mpg, 
                         "Average Highway MPG": highway_mpg})

fuel_mpg.index.name = 'Fuel Type'
fuel_mpg
# Out:
#              Average City MPG  Average Highway MPG
# Fuel Type
# Diesel                  25.60                32.55
# E85                     10.68                15.20
# Gasoline                18.16                25.17
# Natural Gas             24.00                36.00

# %%
plt.plot(fuel_mpg)
# Out:
# [<matplotlib.lines.Line2D at 0x292a0e66430>,
#  <matplotlib.lines.Line2D at 0x292a0e663d0>]
